# %% [markdown]
# ## Key points
# + 机器学习的基本概念
# + 数据分布、数据预处理
# + Linear Regression, Logstic Regression
# + Gredient Descent
# + 作业练习

# %% [markdown]
# ## 基础概念复习

# %% [markdown]
# 1. 机器学习方法主要用在什么特点的常见下？

# %% [markdown]
# Ans: 比较复杂，无法通过编程来处理的情况下，情况非常多，

# %% [markdown]
# 2. 提出 3 个你认为使用了机器学习方法的现实场景.

# %% [markdown]
# Ans: Face recognition, automatic driving, machine translation

# %% [markdown]
# 3. 提出 3 个你认为可以使用机器学习但是还没有使用机器学习方法的场景.

# %% [markdown]
# Ans:
# + 农业领域：土壤健康检测，环境质量检测，
# + 网络安全：异常流量检测，攻击流量识别等

# %% [markdown]
# 4. 什么是“模型”？ 为什么说“All models are wrong, but some useful”.

# %% [markdown]
# Ans:模型是描述客观世界的数学模型，是描述客观世界的规律，从数据中抽象出来的规律集合。

# %% [markdown]
# 5. Classification 和 Regressionu主要针对什么？ 有什么区别？

# %% [markdown]
# Ans:
# + Classification：是指分类问题，预测的结果是离散的，标签数据，如明天下不下雨。
#
# + Regression ：是指回归（预测）问题，得到的结果是连续的，有实际意义的，如明天的气温。

# %% [markdown]
# 6. precision， recall，f1, auc 分别是什么意思？ 假设一个城市有 10000 人，有 30 个犯罪分子，警察抓到了 35 个人，其中 20 个是犯罪分子，请问这个警察的 precision, recall, f1,auc 分别是什么？

# %% [markdown]
# Ans:
# + Precision：表示预测为正样本中有多少个是真正的正样本，$20/35 = \frac{4}{7}$
# + Recall： 表示预测结果中，覆盖了多少正确的正样本， $20/30 = \frac{2}{3}$
# + F1-score: 是将precision 和 recall合并成一个指标，$F1_{score} = \frac{2*precision*recall}{precision+recall} = \frac{8}{13}$
# + AUC : 是ROC曲线对横轴的面积，ROC曲线：横轴是$FPR = \frac{FP}{TN+FP}$，纵轴是$TPR=\frac{TP}{TP+FN} =Recall$

# %% [markdown]
# 7. 请提出两种场景，第一种场景下，对模型的评估很注重 precision, 第二种很注重 recall.

# %% [markdown]
# Ans:
# + 在信贷领域，进行信用评级时，比较注重precision，这样才能尽可能的避免资金损失，
# + 检测是否有病的问题上，看中recall，重点关注覆盖了多少病人

# %% [markdown]
# 8. 什么是 Overfitting， 什么是 Underfitting?

# %% [markdown]
# Ans:
# + Overfitting：过拟合，模型过度拟合了训练数据的内在联系，包括一些噪声数据，这样模型在训练数据上表现很好，在非训练数据上表现不好
# + Underfitting：欠拟合，模型没有学到数据的内在联系，由于模型太简单了，无法刻画一下复杂的情形。

# %% [markdown]
# 9. Lazy-Learning， Lazy在哪里？

# %% [markdown]
# Ans:
# + Lazy-Learning：这种方式指不是根据样本建立一般化的目标函数并确定其参数，而是简单地把训练样本存储起来，直到需要分类新的实例时才分析其所存储样例的关系。只有需要决策时才会利用已有数据进行决策。例如KNN
# + lazy体现在只有需要决策的时候才会利用已有数据进行决策

# %% [markdown]
# 10. Median， Mode， Mean分别是什么？ 有什么意义？

# %% [markdown]
# Ans:
# + Median：中位数，描述数据的一些统计特性
# + mode：众数
# + Mean：平均数

# %% [markdown]
# 11. Outlinear（异常值、离群值）是什么？ 如何定义？

# %% [markdown]
# Ans:
# + Outlinear：数据中有时会包含一个或者多个数值异常大或者异常小的值。
# + 定义：离散点是一个对象，关于数据的概率分布模型，它具有低概率

# %% [markdown]
# 12. Bias 和 Variance 有什么关系？ 他们之间为什么是一种 tradeoff 的？

# %% [markdown]
# Ans:
# + bias：偏差，描述的是通过学习拟合出来的结果的期望，与真实规律之间的差距
# + Variance：方差，描述的是通过学习拟合出来的结果自身的不稳定性
# + 联系：有监督学习中，预测误差的主要来源就是bias和variance，模型的性能取决于bias与variance的tradeoff
# + why？低的偏差，低的方差，才能使得模型更加准确，如何协调low bias 和low variance，就是要找到一个最佳平衡点，使得模型更加准确，如果模型复杂度大于平衡点，则模型的variance会偏高，模型倾向于过拟合，如果模型的复杂度小于平衡点，则模型bias会偏高，模型倾向于过拟合

# %% [markdown]
# 13. Train， Validation，Test 数据集之间是什么关系？ 为什么要这么划分？

# %% [markdown]
# Ans:
# + train data：目的是训练模型的参数
# + validation：用来做模型选择，即做模型的最终优化及确定的
# + Test data：测试已经训练好的模型的推广能力
# + 训练数据和验证数据是相互独立的，使用的是不同的数据
# + 模型需要训练数据来拟合模型，训练模型的参数，而验证数据是用来调整模型参数从而选择最优模型，然后使用测试数据去评估模型的表现，但是并不会调整优化模型

# %% [markdown]
# 14. Supervised Learning 的 Supervised 体现在什么地方？

# %% [markdown]
# Ans:
# + 有目标学习，对模型输出结果有明确的预期输出

# %% [markdown]
# 15. Linear Regression 中，什么是“线性关系”？

# %% [markdown]
# Ans:
# + 线性回归是利用线性回归方差的最小平方函数，对一个或多个自变量和因变量之间关系建模的一种回归分析，这种函数是一个或者多个回归系数的模型参数的线性组合，

# %% [markdown]
# 16. Linear Regression中，Loss 函数怎么定义的？ 为什么要写成这样？ 什么是凸函数？ 优化中有什么意义？

# %% [markdown]
# Ans:
# + loss：平方损失函数$loss = \sum_{i=1}^n(y_i-\bar{y})^2$
# + 为什么使用平方：使用的是最小二乘的思想，利用平方来度量观测点与估计点的距离（远近），最小指的是参数值要保证各个观测点与估计点的距离的平方和达到最小
# + 凸函数：定义在某个向量空间的凸子集上的实值函数，其在函数图像上方的点集为一个凸集
# + 凸优化：**针对凸优化问题，能够比较有效的找到全局最优解**，因此现实生活中很多计算量接近无穷大的问题时，想办法将模型转换成凸优化问题，然而很多问题都不是凸优化问题，因此凸优化很重要。

# %% [markdown]
# 17. 简述Gradient Descent的过程，以 $y = -10 * x^2 + 3x + 4 $ 为例，从一个任一点 $ x = 10 $ 开始，如果根据 Gradient Descent 找到最值。

# %% [markdown]
# Ans:
# + 用直观的例子解释。比如我们在一座大山上的某处位置，由于我们不知道怎么下山，于是决定走一步算一步，也就是在每走到一个位置的时候，求解当前位置的梯度，沿着梯度的负方向，也就是当前最陡峭的位置向下走一步，然后继续求解当前位置梯度，向这一步所在文职沿着最陡峭最易下山的位置走一步，这样一步步走下去，一直走到觉得我们已经到了山脚。有可能是到了一个局部的山脚。
# > 梯度下降算法求解最值问题：
# > 1. 求导 $f^{'}(x) = -20 * x +3$
# > 2. 每一步的迭代公式是$x_{i+1} = x_i + \eta f^{'}(x_i)$，求最大值所以是加号,**最大值4.225**，如果$|x_{i+1} -x_i|<0.4$则终止计算
# > 3. 选定初始值 $x_0=10, \eta = 0.004$ (初始值随便设置)，接下来开始计算：
# >> 1. $x_1 = x_0+ \eta f^{'}(x_0) = 10+0.004*((-20)*10+3) = 9.212$
# >> 2. $x_2 = x_1+ \eta f^{'}(x_1) = 8.48704$
# >> 3. $x_3 = x_2+ \eta f^{'}(x_2) = 7.820$
#
# >>  $x_{10} = x_9+ \eta f^{'}(x_9) = 4.4287$
# >> 此时$|x_{10} -x_9|<0.4$，精度足够，计算终止，此时4.428很接近真实解4.225
# >>
# >>

# %% [markdown]
# 18. 一般在机器学习数量时，会做一个预处理（Normalization）， 简述 Normalization 的过程，以及数据经过 Normalization之后的平均值和标准差的情况。

# %% [markdown]
# Ans:
# + 是将数据按比例缩放，使之落到一个小的特定区间，
# + 求出数据的平均值$\bar{X}$和标准差$Std$，然后对每一个数据使用$X_{Nor} = \frac{x - \bar{X}}{Std} $进行标准化。
# + 标准化后，数据被映射到某种特定的分布中，均值为0，方差为1

# %% [markdown]
# 19. Logstic Regression 的 Logstic 是什么曲线，被用在什么地方？

# %% [markdown]
# Ans:
# + 逻辑回归是一个S型的曲线，能够把值映射到（0，1）之间，$y = \frac{1}{1+e^{-x}}$
# + logstic regression常见的应用场景就是预测概率，如根据一个人的一些特征预测其患心脏病的概率等

# %% [markdown]
# 20. Logstic Regression 的 Loss 函数 Cross Entropy 是怎么样的形式？ 有什么意义？

# %% [markdown]
# Ans
# + Cross Entropy:$loss = - \sum(y_i log\hat{y})$
# + 描述了两个不通过概率分布$y_i $和$ \hat{y}$的差异程度，两个分布差异越大，则交叉熵的差异越大

# %% [markdown]
# ## 问题实战

# %% [markdown]
# 问题描述： 在新闻出版业中一个常常的问题就是新闻版权抄袭，所以我们现在为了避免这个事情，需要建立一个模型，判断这个文章是不是由某个新闻出版单位出版的。 在我们这个问题里，我们需要建立一个模型，该模型接受一个作为文本的输入，然后判断该文本是不是由“新华社”发布的。

# %% [markdown]
# Enviroment:
#
# + Python 3.6
# + numpy
# + scikit learning

# %%
# !pwd
# Out:
# /Users/heany/code/AI-For-NLP

# %% [raw]
# ###

# %% [markdown]
# **请在 pycharm 中运行程序，该处只作为关键信息的记录。 **

# %% [markdown]
# 1. 问什么此问题应该用机器学习方法？

# %% [markdown]
# Ans：

# %% [markdown]
# 2. 问什么要对文本进行向量化？ 如何进行文本向量化表示？ （请使用tfidf 或者词向量）

# %% [markdown]
# Ans:

# %% [markdown]
# hint: 如果你使用 tfidf，则需要 scikit learning 如果你需要词向量，则需要 gensim

# %% [markdown]
# 3. 请对数据进行Preprocessing, Normalization 操作
# （你需要在 Preprocssing 的时候，把文章开头的“新华社”3 个字去掉。如果不去掉，会出现什么问题？）

# %% [markdown]
# 4. 请确定模型的 Baseline 以及确定评测指标（Evaluation）.

# %% [markdown]
# 5. 尝试不同的模型、不同的参数，观察结果变化。

# %% [markdown]
# 6. 依据模型的表现，进行参数调节。
